# %%
import random
import pandas as pd
from typing import TypeVar, List, Tuple
from sentenceQuality import sentenceQuality

# Group: Jonah Mulcrone, Brian Sung, Emmanuel Obikwelu

X = TypeVar('X') # This is a generic type to represent a data point

def split_data(data: List[X], prob: float) -> Tuple[List[X], List[X]]:
    """This function splits the data into pieces"""
    
    data = data[:]
    random.shuffle(data)
    cut = int(len(data) * prob)
    return data[:cut], data[cut:]

data = [n for n in range(1000)]               # List of values ranging from 0 to 1000
train, test = split_data(data, 0.75)

# Making sure the function does what we intend
assert len(train) == 750
assert len(test) == 250

assert sorted(train + test) == data

#####################################
#    Pair input/output variables    #
#####################################

Y = TypeVar('Y') # Represents output variables


def train_test_split(xs: List[X], 
                    ys: List[Y], 
                    test_pct: float) -> Tuple[List[X], List[X], List[Y], List[Y]]:
    
    idxs = [i for i in range(len(xs))]
    train_idxs, test_idxs = split_data(idxs, 1 - test_pct)
    
    return ([xs[i] for i in train_idxs],
            [xs[i] for i in test_idxs],
            [ys[i] for i in train_idxs],
            [ys[i] for i in test_idxs])

##########################################
#    Making sure the code works right    #
##########################################

xs = [x for x in range(1000)]
ys = [2 * x for x in xs]
x_train, x_test, y_train, y_test = train_test_split(xs, ys, 0.25)


# Make sure the datasets are the right lengths
assert len(x_train) == len(y_train) == 750
assert len(x_test) == len(y_test) == 250


# Check that data points are paired correctly
assert all(y == 2 * x for x, y in zip(x_train, y_train))
assert all(y == 2 * x for x, y in zip(x_test, y_test))

#################################
#    Machine learning basics    #
#################################

def accuracy(tp: int, fp: int, fn: int, tn: int) -> float:
    correct = tp + tn
    total = tp + fp + fn + tn
    
    return correct / total

assert accuracy(70, 4930, 13930, 981070) == 0.98114

def precision(tp: int, fp: int, fn: int, tn: int) -> float:
    return tp / (tp + fp)

assert precision(70, 4930, 13930, 981070) == 0.014

def recall(tp: int, fp: int, fn: int, tn: int) -> float:
    return tp / (tp + fn)
           
assert recall(70, 4930, 13930, 981070) == 0.005



# Main Method

file = pd.read_csv('Best-Selling-Book-Reviews.csv')
df = file[['review title']].head(250)

"""Split the Data into Training and Testing"""

train, test = split_data(df['review title'].values, 0.75)
print(train)

obj = sentenceQuality()

quality_scores = []

# Create Quality Scores for Reviews

for review in train:
    quality_scores.append(str(round(obj.calculateQuality(obj.calculateScores(review)), 1)))

# Create Dataframe with Reviews Mapping to Scores

df_train_scores = pd.DataFrame({
    'Review Title': train,
    'Quality': quality_scores
})

print(df_train_scores)

# Train Test Split

x_train, x_test, y_train, y_test = train_test_split(df_train_scores['Review Title'].values, df_train_scores['Quality'].values, 0.25)
# Out:
# Sentiment(polarity=1.0, subjectivity=0.3)
# 8.0
# 35.0
# The scores for your input is [0.43, 1.0, 0.3, 0.2876249999999999]
# Sentiment(polarity=1.0, subjectivity=0.3)
# 8.0
# 35.0
# The final quality for your input is 0.50440625
# ["My granddaughter's favorite!" 'Ted Bundy, Coriolanus and The Joker'
#  'It’s as if he sacrificed characters for beautiful prose.'
#  '"We can live as cowards or die as riders."' 'So fun!'
#  'Book in GREAT condition' 'In her words, heartbreaking and hopeful'
#  'Living the Wordh' 'A Beautiful And Enlightening World War II Novel'
#  'Powerful Book' 'Truth about the Word' 'Love it' 'Great Book on PTSD'
#  'Pretty Good....' 'Boys' 'Carried Away to Another World' 'Great book'
#  '90s flashback' 'Excellent' 'Cute little story'
#  'Lords of Discipline + Dragonriders of Pern + ...steamy romance? But it works!'
#  'So Good!!!' 'Such a cute book!' 'Great gift'
#  'DANGER: read at your own risk' 'Funny 4th Grade Read Aloud'
#  'Clear + Practical SelfHelp Book For Those Wanting to Improve Productivity'
#  '4.5 Stars' 'Funny' 'My grandson loves reading this book!'
#  'Good but not great followup to The Firm' 'So cute!'
#  'Not Really a "Kiss and Tell" but Maybe a "Drug and Tell"'
#  'What a fun book - Lovely sounds and Pictures' 'Good read' 'Cute'
#  'Our Queen has spoken!' 'It’s such a cute book!'
#  'DO NOT READ THE EPILOGUE TO THIS BOOK. IT COMPLETELY RUINS THE BOOK!!!!'
#  'Excellent Read' 'Shameful history, essential reading'
#  'Highly Recommend!' 'An even deeper and more sinister layer'
#  'Transform Your Life with "Atomic Habits' 'A perfect gift' 'Fun book!'
#  'Beyond the Content, Lies the Conversation'
#  'Welcome to the World of Navarre!' 'A tragic and memorable tale'
#  'Great Book for 3year old' 'Delivered not damaged' 'Wow!' 'Nice'
#  'Stunning' 'STUNNING'
#  'I will be rereading this book my whole life I loved it so much!' 'Night'
#  'Buy this book!' 'Fast Read, Sad Story' 'Great' 'Rapture ready'
#  'If you love the hunger games Buy this Book!!!!'
#  'review from my daughter: good' 'An Absolute Rollercoaster'
#  'I needed this book!' 'Should be requested reading in history classes'
#  'What a Cute Story!!' 'Adorable'
#  'Distilled and clear ideas made into a simple system of behavior change. Top notch!'
#  'I hate reading' 'Lovely story for my childrens school project'
#  'Britney you are so invincible! You are an inspiration and helped motivate me to be strong like you.'
#  'Perfect for any Swiftie!' 'Love it!' 'Glad I finally started ACOTAR'
#  'Not a Bit Over-Hyped' 'Cute Book' 'Best book I have read in 10+ years'
#  'Chemistry lessons and so much more!'
#  'I can’t believe I waited so long to read this epic book'
#  'What is most disquieting about the crimes in Killers of the Flower Moon is the awesome extent of corruption that is revealed in'
#  'My kids have loved for years' 'Classic'
#  'Cute story, very durable material!' 'The gift of my personal holocost'
#  'Uncomfortable but important read!' 'Best Book Ever - from a 10 year old'
#  'Storyteller Extraordinaire - John Grisham' 'Great book!'
#  'This Book!!! Everyone Needs To Read It Immediately'
#  'Updated review after 100 days building small yet lasting habits.' 'Book'
#  'AMAZING, BEST BOOK OF 2023' 'Explains the No Brainer title well'
#  'Lives up to they hype!'
#  'An intimate retelling of a story you think you know!' 'Fascinating Book'
#  'Cute read aloud' '11 Year Old Son LOVED it' 'Doesn’t deserve the hate'
#  'A MOST INTERESTING BOOK!' 'A must read'
#  'This book should come with trigger warnings.' 'Mo Willems Wins again'
#  'Bow Down to the Queen of YA Fantasy'
#  'Great book. Damaged during shipping'
#  'Another Largely Forgotten Piece of American History, Brought Back to Life'
#  'Atomic Habits will change your life! 9 takeaways:'
#  'Great follow up Grisham book!' 'Baby’s favorite book'
#  'Brilliantly written!' 'should be required reading' 'So Good'
#  'Matter of Fact Horrors' 'I made so many connections'
#  "One of my autistic son's favorite books"
#  'Do you want to feel like a baddie?'
#  'Fun for all ages and encourages kids to read!' 'Amazing'
#  'Great story for kids' 'One of my favorite childhood books'
#  'All good things!' 'Humorous read aloud' 'Funny lol'
#  "Transforming Through Tiny Changes: A Deep Dive into 'Atomic Habits"
#  'Excellent!' 'Fun game' 'Great book' 'A different read' 'Loved it!'
#  'Mo Willems ... amazing author' 'Quite the read...' 'Love it'
#  'A fun read' 'What a heartbreaking story' 'Brilliant Historical Fiction'
#  'A fresh, exciting sequel to The Firm'
#  'Seasons / fall book for young kids'
#  "A must-read for anyone who's seeking freedom or overcoming imposter syndrome"
#  'So adorable' 'This is not a hero story'
#  'as if this book needs more hyperbolic praise…' 'Brutally honest'
#  'I would say that I do recommend this book, but absolutely NOT to everyone.'
#  'Happy sis' 'Haunting and powerfully tragic ...' 'Bittersweet'
#  'Transformative and Insightful - A Must-Read Gem!'
#  'Chemical Reaction Retraction' 'Arrived in perfect shape'
#  'My sons favorite' 'A little long' '3 year old class loved !'
#  "An author's initial perspective on The Ballad of Songbirds and Snakes"
#  'Witness to Unspeakable Horrors of the Holocaust'
#  'Survival of the fittest on a whole other level'
#  'A self defense weapon book that is NEEDED!'
#  'mentioned that Mendes-France was suffering like Jesus, Elie Wiesel responded'
#  'Please buy this book and start loving your life'
#  'Lots of fun info for young Swifties' 'Favorite childhood book'
#  'My son love it! Crazy about it!' 'Kids Love Eric Carle!' 'Raw and Real'
#  'kids love it' 'Great product' 'Book' 'Great series'
#  'One of our favorite children’s fall themed books' 'Very cute book'
#  'Amazing!' 'Beautiful and devastating.'
#  'Toddler loves it! Not sturdy though' "I'm So Glad I Read This Book!"
#  '⭐️⭐️⭐️⭐️⭐️ life changing read' 'The amount and scale of the research'
#  "48 laws of power which don't make loads of sense at first so it has examples."
#  'Fun Family gift' 'Funny as usual' 'I LOVE THIS BOOK!! 😍 ⭐️⭐️⭐️⭐️⭐️'
#  'A Must Read' 'love this author and series'
#  'Cute book but arrived damaged' "Perfect children's book for fall"
#  'A certified page turner' 'Love' 'Solid']
# Sentiment(polarity=0.625, subjectivity=1.0)
# 4.0
# 24.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 29.0
# Sentiment(polarity=0.85, subjectivity=1.0)
# 11.0
# 46.0
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)
# 9.0
# 31.0
# Sentiment(polarity=0.375, subjectivity=0.2)
# 2.0
# 5.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 4.0
# 20.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 33.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 3.0
# 14.0
# Sentiment(polarity=0.575, subjectivity=0.7)
# 8.0
# 40.0
# Sentiment(polarity=0.3, subjectivity=1.0)
# 2.0
# 12.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 17.0
# Sentiment(polarity=0.5, subjectivity=0.6)
# 2.0
# 6.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 4.0
# 15.0
# Sentiment(polarity=0.475, subjectivity=0.8)
# 2.0
# 10.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 1.0
# 4.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 5.0
# 25.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 2.0
# 9.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 2.0
# 12.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 1.0
# 9.0
# Sentiment(polarity=0.15625, subjectivity=0.75)
# 3.0
# 15.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 11.0
# 58.0
# Sentiment(polarity=1.0, subjectivity=0.6000000000000001)
# 2.0
# 6.0
# Sentiment(polarity=0.3125, subjectivity=0.75)
# 4.0
# 13.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 2.0
# 9.0
# Sentiment(polarity=0.6, subjectivity=1.0)
# 6.0
# 23.0
# Sentiment(polarity=0.25, subjectivity=1.0)
# 5.0
# 22.0
# Sentiment(polarity=0.10000000000000002, subjectivity=0.3833333333333333)
# 10.0
# 62.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 2.0
# 7.0
# Sentiment(polarity=0.25, subjectivity=1.0)
# 1.0
# 5.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 30.0
# Sentiment(polarity=0.033333333333333305, subjectivity=0.5833333333333334)
# 8.0
# 32.0
# Sentiment(polarity=0.625, subjectivity=1.0)
# 2.0
# 6.0
# Sentiment(polarity=-0.1, subjectivity=0.2)
# 12.0
# 41.0
# Sentiment(polarity=0.4, subjectivity=0.475)
# 8.0
# 35.0
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# 2.0
# 8.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 1.0
# 4.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 17.0
# Sentiment(polarity=0.3125, subjectivity=0.75)
# 7.0
# 16.0
# Sentiment(polarity=-0.3662109375, subjectivity=0.2)
# 13.0
# 54.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 2.0
# 13.0
# Sentiment(polarity=0.0, subjectivity=0.3)
# 4.0
# 31.0
# Sentiment(polarity=0.2, subjectivity=0.5399999999999999)
# 2.0
# 15.0
# Sentiment(polarity=0.0, subjectivity=0.75)
# 7.0
# 32.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 33.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 3.0
# 12.0
# Sentiment(polarity=0.375, subjectivity=0.2)
# 2.0
# 7.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 35.0
# Sentiment(polarity=1.0, subjectivity=0.9)
# 6.0
# 26.0
# Sentiment(polarity=-0.125, subjectivity=0.875)
# 5.0
# 23.0
# Sentiment(polarity=0.45, subjectivity=0.475)
# 5.0
# 20.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 3.0
# 19.0
# Sentiment(polarity=0.125, subjectivity=1.0)
# 1.0
# 3.0
# Sentiment(polarity=0.6, subjectivity=1.0)
# 1.0
# 4.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 1.0
# 8.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 1.0
# 8.0
# Sentiment(polarity=0.3833333333333333, subjectivity=0.46666666666666673)
# 14.0
# 49.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 1.0
# 5.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 3.0
# 11.0
# Sentiment(polarity=-0.15, subjectivity=0.8)
# 4.0
# 16.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 1.0
# 5.0
# Sentiment(polarity=0.2, subjectivity=0.5)
# 2.0
# 12.0
# Sentiment(polarity=1.0, subjectivity=0.6)
# 9.0
# 34.0
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# 5.0
# 24.0
# Sentiment(polarity=0.2, subjectivity=0.9)
# 3.0
# 23.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 15.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 7.0
# 40.0
# Sentiment(polarity=0.78125, subjectivity=1.0)
# 4.0
# 14.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 1.0
# 8.0
# Sentiment(polarity=0.24166666666666667, subjectivity=0.4134920634920635)
# 14.0
# 67.0
# Sentiment(polarity=-0.8, subjectivity=0.9)
# 3.0
# 12.0
# Sentiment(polarity=0.5, subjectivity=0.75)
# 7.0
# 38.0
# Sentiment(polarity=0.4333333333333333, subjectivity=0.7333333333333333)
# 18.0
# 80.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 4.0
# 20.0
# Sentiment(polarity=0.625, subjectivity=0.6)
# 2.0
# 6.0
# Sentiment(polarity=0.25, subjectivity=1.0)
# 5.0
# 25.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 16.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 2.0
# 8.0
# Sentiment(polarity=1.0, subjectivity=0.3)
# 8.0
# 26.0
# Sentiment(polarity=0.625, subjectivity=0.5)
# 6.0
# 29.0
# Sentiment(polarity=0.025, subjectivity=0.4)
# 14.0
# 43.0
# Sentiment(polarity=0.75, subjectivity=0.75)
# 23.0
# 105.0
# Sentiment(polarity=0.7, subjectivity=0.8)
# 6.0
# 23.0
# Sentiment(polarity=0.16666666666666666, subjectivity=0.16666666666666666)
# 1.0
# 7.0
# Sentiment(polarity=0.375, subjectivity=0.65)
# 5.0
# 28.0
# Sentiment(polarity=0.0, subjectivity=0.3)
# 6.0
# 27.0
# Sentiment(polarity=0.0, subjectivity=1.0)
# 4.0
# 29.0
# Sentiment(polarity=0.55, subjectivity=0.25)
# 8.0
# 26.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 36.0
# Sentiment(polarity=1.0, subjectivity=0.75)
# 2.0
# 9.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 8.0
# 40.0
# Sentiment(polarity=-0.125, subjectivity=0.2)
# 10.0
# 54.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 1.0
# 4.0
# Sentiment(polarity=0.8, subjectivity=0.6)
# 5.0
# 21.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 29.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 5.0
# 17.0
# Sentiment(polarity=0.25, subjectivity=0.6)
# 10.0
# 42.0
# Sentiment(polarity=0.7, subjectivity=0.8500000000000001)
# 2.0
# 15.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 3.0
# 13.0
# Sentiment(polarity=0.39999999999999997, subjectivity=0.5)
# 6.0
# 19.0
# Sentiment(polarity=-0.8, subjectivity=0.9)
# 6.0
# 20.0
# Sentiment(polarity=0.5625, subjectivity=0.5)
# 4.0
# 20.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 3.0
# 9.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 7.0
# 37.0
# Sentiment(polarity=0.3, subjectivity=0.2)
# 4.0
# 18.0
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# 8.0
# 28.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 5.0
# 30.0
# Sentiment(polarity=0.07142857142857142, subjectivity=0.14285714285714285)
# 11.0
# 62.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 8.0
# 40.0
# Sentiment(polarity=1.0, subjectivity=0.75)
# 5.0
# 24.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 5.0
# 17.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 2.0
# 18.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 23.0
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# 2.0
# 6.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 19.0
# Sentiment(polarity=0.5, subjectivity=0.5)
# 5.0
# 22.0
# Sentiment(polarity=0.15, subjectivity=0.6)
# 8.0
# 32.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 8.0
# 26.0
# Sentiment(polarity=0.375, subjectivity=0.2)
# 9.0
# 36.0
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)
# 1.0
# 7.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 4.0
# 17.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 6.0
# 29.0
# Sentiment(polarity=0.875, subjectivity=0.6000000000000001)
# 3.0
# 13.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 3.0
# 17.0
# Sentiment(polarity=0.525, subjectivity=0.85)
# 2.0
# 8.0
# Sentiment(polarity=0.0, subjectivity=0.45)
# 10.0
# 55.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 1.0
# 9.0
# Sentiment(polarity=-0.05000000000000002, subjectivity=0.30000000000000004)
# 2.0
# 7.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 2.0
# 9.0
# Sentiment(polarity=0.0, subjectivity=0.6)
# 3.0
# 14.0
# Sentiment(polarity=0.875, subjectivity=0.8)
# 2.0
# 7.0
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)
# 4.0
# 22.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 3.0
# 12.0
# Sentiment(polarity=0.5, subjectivity=0.6)
# 2.0
# 6.0
# Sentiment(polarity=0.3, subjectivity=0.2)
# 3.0
# 8.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 23.0
# Sentiment(polarity=0.45, subjectivity=0.5)
# 3.0
# 26.0
# Sentiment(polarity=0.13333333333333333, subjectivity=0.5666666666666668)
# 7.0
# 29.0
# Sentiment(polarity=0.1, subjectivity=0.4)
# 6.0
# 27.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 12.0
# 64.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 2.0
# 10.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 19.0
# Sentiment(polarity=0.5, subjectivity=0.5)
# 8.0
# 37.0
# Sentiment(polarity=0.6, subjectivity=0.9)
# 2.0
# 14.0
# Sentiment(polarity=-0.1, subjectivity=0.9)
# 14.0
# 59.0
# Sentiment(polarity=0.8, subjectivity=1.0)
# 2.0
# 8.0
# Sentiment(polarity=-0.75, subjectivity=0.75)
# 4.0
# 27.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 1.0
# 11.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 39.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 3.0
# 26.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 4.0
# 21.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 3.0
# 14.0
# Sentiment(polarity=-0.11875, subjectivity=0.45)
# 3.0
# 11.0
# Sentiment(polarity=0.4875, subjectivity=0.5)
# 5.0
# 18.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 12.0
# 58.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 7.0
# 41.0
# Sentiment(polarity=0.037500000000000006, subjectivity=0.3875)
# 9.0
# 38.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 8.0
# 34.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 10.0
# 65.0
# Sentiment(polarity=0.6, subjectivity=0.95)
# 9.0
# 39.0
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004)
# 7.0
# 29.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 3.0
# 21.0
# Sentiment(polarity=-0.0625, subjectivity=0.75)
# 7.0
# 23.0
# Sentiment(polarity=0.625, subjectivity=0.6)
# 4.0
# 17.0
# Sentiment(polarity=-0.015384615384615385, subjectivity=0.3807692307692308)
# 3.0
# 10.0
# Sentiment(polarity=0.5, subjectivity=0.6)
# 3.0
# 10.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 2.0
# 12.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 1.0
# 4.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 2.0
# 11.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 10.0
# 40.0
# Sentiment(polarity=0.65, subjectivity=1.0)
# 3.0
# 12.0
# Sentiment(polarity=0.7500000000000001, subjectivity=0.9)
# 1.0
# 7.0
# Sentiment(polarity=-0.07500000000000001, subjectivity=1.0)
# 3.0
# 23.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 29.0
# Sentiment(polarity=0.625, subjectivity=1.0)
# 8.0
# 21.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 16.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 7.0
# 30.0
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# 17.0
# 60.0
# Sentiment(polarity=0.3, subjectivity=0.2)
# 3.0
# 13.0
# Sentiment(polarity=0.0, subjectivity=0.625)
# 3.0
# 12.0
# Sentiment(polarity=0.78125, subjectivity=0.6)
# 6.0
# 13.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 3.0
# 9.0
# Sentiment(polarity=0.5, subjectivity=0.6)
# 5.0
# 23.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 5.0
# 25.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 6.0
# 27.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 20.0
# Sentiment(polarity=0.5, subjectivity=0.6)
# 1.0
# 4.0
# Sentiment(polarity=0.0, subjectivity=0.1)
# 1.0
# 5.0
#                                           Review Title Quality
# 0                         My granddaughter's favorite!     0.7
# 1                  Ted Bundy, Coriolanus and The Joker       0
# 2    It’s as if he sacrificed characters for beauti...     0.7
# 3           "We can live as cowards or die as riders."     0.2
# 4                                              So fun!    -0.1
# ..                                                 ...     ...
# 182                      Cute book but arrived damaged     0.6
# 183                   Perfect children's book for fall     0.6
# 184                            A certified page turner       0
# 185                                               Love     0.2
# 186                                              Solid       0
#
# [187 rows x 2 columns]
