# %%
import random
import pandas as pd
from typing import TypeVar, List, Tuple
from sentenceQuality import sentenceQuality

# Group: Jonah Mulcrone, Brian Sung, Emmanuel Obikwelu

X = TypeVar('X') # This is a generic type to represent a data point

def split_data(data: List[X], prob: float) -> Tuple[List[X], List[X]]:
    """This function splits the data into pieces"""
    
    data = data[:]
    random.shuffle(data)
    cut = int(len(data) * prob)
    return data[:cut], data[cut:]

data = [n for n in range(1000)]               # List of values ranging from 0 to 1000
train, test = split_data(data, 0.75)

# Making sure the function does what we intend
assert len(train) == 750
assert len(test) == 250

assert sorted(train + test) == data

#####################################
#    Pair input/output variables    #
#####################################

Y = TypeVar('Y') # Represents output variables


def train_test_split(xs: List[X], 
                    ys: List[Y], 
                    test_pct: float) -> Tuple[List[X], List[X], List[Y], List[Y]]:
    
    idxs = [i for i in range(len(xs))]
    train_idxs, test_idxs = split_data(idxs, 1 - test_pct)
    
    return ([xs[i] for i in train_idxs],
            [xs[i] for i in test_idxs],
            [ys[i] for i in train_idxs],
            [ys[i] for i in test_idxs])

##########################################
#    Making sure the code works right    #
##########################################

xs = [x for x in range(1000)]
ys = [2 * x for x in xs]
x_train, x_test, y_train, y_test = train_test_split(xs, ys, 0.25)


# Make sure the datasets are the right lengths
assert len(x_train) == len(y_train) == 750
assert len(x_test) == len(y_test) == 250


# Check that data points are paired correctly
assert all(y == 2 * x for x, y in zip(x_train, y_train))
assert all(y == 2 * x for x, y in zip(x_test, y_test))

#################################
#    Machine learning basics    #
#################################

def accuracy(tp: int, fp: int, fn: int, tn: int) -> float:
    correct = tp + tn
    total = tp + fp + fn + tn
    
    return correct / total

assert accuracy(70, 4930, 13930, 981070) == 0.98114

def precision(tp: int, fp: int, fn: int, tn: int) -> float:
    return tp / (tp + fp)

assert precision(70, 4930, 13930, 981070) == 0.014

def recall(tp: int, fp: int, fn: int, tn: int) -> float:
    return tp / (tp + fn)
           
assert recall(70, 4930, 13930, 981070) == 0.005



# Main Method

file = pd.read_csv('Best-Selling-Book-Reviews.csv')
df = file[['review title']].head(250)

"""Split the Data into Training and Testing"""

train, test = split_data(df['review title'].values, 0.75)
print(train)

obj = sentenceQuality()

quality_scores = []

# Create Quality Scores for Reviews

for review in train:
    quality_scores.append(str(round(obj.calculateQuality(obj.calculateScores(review)), 1)))

# Create Dataframe with Reviews Mapping to Scores

df_train_scores = pd.DataFrame({
    'Review Title': train,
    'Quality': quality_scores
})

print(df_train_scores)

# Train Test Split

x_train, x_test, y_train, y_test = train_test_split(df_train_scores['Review Title'].values, df_train_scores['Quality'].values, 0.25)
# Out:
# Sentiment(polarity=1.0, subjectivity=0.3)
# 8.0
# 35.0
# The scores for your input is [0.43, 1.0, 0.3, 0.2876249999999999]
# Sentiment(polarity=1.0, subjectivity=0.3)
# 8.0
# 35.0
# The final quality for your input is 0.50440625
# ['Great follow up Grisham book!' 'Great book' 'Cute'
#  "Transforming Through Tiny Changes: A Deep Dive into 'Atomic Habits"
#  'One of my favorite reads this year!' 'hard to put down…'
#  'Brilliantly written!' 'Great for Toddlers'
#  '4.75-Stars: Excruciating and Diabolical, but Masterfully Written'
#  'Another great book from Mo Willems' 'Stunning'
#  'Clear + Practical SelfHelp Book For Those Wanting to Improve Productivity'
#  'This is not a hero story' '11 Year Old Son LOVED it' 'A different read'
#  'The gift of my personal holocost' 'Buy it, it’s worth the read!'
#  'Delivered not damaged' 'Excellent Read' 'Classic' 'I had no idea...'
#  'Fun book!' 'Great book series for kids' 'My kids have loved for years'
#  'My son love it! Crazy about it!' 'Book in GREAT condition'
#  'Matter of Fact Horrors' 'Fun book' 'Best Book Ever - from a 10 year old'
#  'A self defense weapon book that is NEEDED!' 'Very good'
#  'Cute story, very durable material!' 'Heartbreaking but beautiful'
#  'Great story for kids' 'Golden Book' 'Love it' 'Nice'
#  'Beyond the Content, Lies the Conversation' 'Love it' 'I hate reading'
#  'So cute!' 'The One with the Double Review' 'Mo Willems Wins again'
#  'Kids Love Eric Carle!' 'So Good!!!'
#  'See the Light through Superb Writing with Profound Lessons'
#  "I'm So Glad I Read This Book!" 'Best book I have read in 10+ years'
#  'My grandson loves reading this book!'
#  'What a fun book - Lovely sounds and Pictures' 'Great End Times source'
#  'STUNNING' 'Liked the international flavor' 'Overall' 'Loved it!'
#  "48 laws of power which don't make loads of sense at first so it has examples."
#  'The Ballad of Songbirds and Snakes' 'Arrived in perfect shape'
#  'It’s as if he sacrificed characters for beautiful prose.'
#  'An intimate retelling of a story you think you know!' 'kids love it'
#  'Great series' 'Night'
#  'Huge toolkit of actionable, practical, organized strategies to build positive habits'
#  'This Book!!! Everyone Needs To Read It Immediately'
#  'I will be rereading this book my whole life I loved it so much!'
#  'What a heartbreaking story' 'Toddler loves it! Not sturdy though'
#  'Great product' "Perfect children's book for fall" 'Book as expected'
#  'This book should come with trigger warnings.' 'Funny lol'
#  'I needed this book!' 'Lives up to they hype!' 'Boys'
#  "Exciting, scary, interesting, but I didn't like it" 'Such a cute book!'
#  'Perfect for any Swiftie!' 'Favorite childhood book'
#  'Unbelievably impressive. Her torn life on paper.'
#  'Lords of Discipline + Dragonriders of Pern + ...steamy romance? But it works!'
#  'Book' 'Amazing' 'A Must Read' 'I hope you read this book'
#  "An author's initial perspective on The Ballad of Songbirds and Snakes"
#  'Brutally honest' 'Fun Family gift' 'My sons favorite'
#  'Riveting Account of Murders of Osage Indians to Steal Their Money'
#  'Adorable'
#  'I would say that I do recommend this book, but absolutely NOT to everyone.'
#  'Funny 4th Grade Read Aloud' 'Awesome book' 'A tragic and memorable tale'
#  "One of my autistic son's favorite books" 'Our Queen has spoken!'
#  'Fun for all ages and encourages kids to read!'
#  '⭐️⭐️⭐️⭐️⭐️ life changing read'
#  'Britney you are so invincible! You are an inspiration and helped motivate me to be strong like you.'
#  'In her words, heartbreaking and hopeful' 'Mo Willems ... amazing author'
#  'Should be requested reading in history classes'
#  'Lots of fun info for young Swifties' 'love this author and series'
#  'Beeautiful'
#  "A must-read for anyone who's seeking freedom or overcoming imposter syndrome"
#  'Bow Down to the Queen of YA Fantasy'
#  'Distilled and clear ideas made into a simple system of behavior change. Top notch!'
#  'I can’t believe I waited so long to read this epic book'
#  'Not a perfect book, but a good book 1.' 'Pigeon books' 'Very cute book'
#  'Love' 'Please buy this book and start loving your life'
#  'Chemical Reaction Retraction' 'review from my daughter: good'
#  'A must read' 'I made so many connections' 'Favorite family activity'
#  'Definitely for 2-5 yo' 'Beautiful Cover'
#  'A Captivating Journey into the Realm of Thorns and Roses'
#  'Uncomfortable but important read!' 'Love it' 'Brilliant'
#  'Shameful history, essential reading' 'Good read'
#  'Some Thoughts about NIGHT -- Today' '3 year old class loved !'
#  'We LOVE the pigeon books!'
#  'Lovely story for my childrens school project' 'Love it!'
#  '“Lost to the World”' 'One of our favorite children’s fall themed books'
#  'Happy sis' 'Raw and Real'
#  'Atomic Habits will change your life! 9 takeaways:' 'What a Cute Story!!'
#  'Fascinating Book' 'A Beautiful And Enlightening World War II Novel'
#  'Fun game' 'Not Really a "Kiss and Tell" but Maybe a "Drug and Tell"'
#  'ஐBeauty and the Beast meets Faerie ஐ' 'Rapture ready'
#  'Not a Bit Over-Hyped' 'An Absolute Rollercoaster'
#  'Made the cutest bday gift' 'Transform Your Life with "Atomic Habits'
#  'Great book' 'A fresh, exciting sequel to The Firm' 'Funny as usual'
#  'Beautiful and devastating.' 'A fun read' 'Pretty Good....'
#  'A very sad read' 'Great Understanding' 'Cute little story'
#  'Sign me up for the threequel!' 'Solid' 'Fast Read, Sad Story'
#  'Brilliant Historical Fiction'
#  'If you love the hunger games Buy this Book!!!!'
#  'Carried Away to Another World' 'Bittersweet'
#  'Britney, do not stop being you!!!' '90s flashback'
#  'What is most disquieting about the crimes in Killers of the Flower Moon is the awesome extent of corruption that is revealed in'
#  'as if this book needs more hyperbolic praise…'
#  'Cute book but arrived damaged' 'Great'
#  'Ted Bundy, Coriolanus and The Joker' "Couldn't Put I Down" 'So fun!'
#  'My daughter loves this book!' 'Chemistry lessons and so much more!'
#  'Transformative and Insightful - A Must-Read Gem!' 'Baby’s favorite book'
#  'Storyteller Extraordinaire - John Grisham'
#  'ACOTAR is nothing more than erotica' 'Great book!'
#  'Grisham disappoints,but worth a read'
#  'DO NOT READ THE EPILOGUE TO THIS BOOK. IT COMPLETELY RUINS THE BOOK!!!!'
#  'All good things!' 'Glad I finally started ACOTAR'
#  'Great book. Damaged during shipping']
# Sentiment(polarity=1.0, subjectivity=0.75)
# 5.0
# 24.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 2.0
# 9.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 1.0
# 4.0
# Sentiment(polarity=0.0, subjectivity=0.45)
# 10.0
# 55.0
# Sentiment(polarity=0.625, subjectivity=1.0)
# 7.0
# 28.0
# Sentiment(polarity=-0.2916666666666667, subjectivity=0.5416666666666666)
# 4.0
# 13.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 2.0
# 18.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 3.0
# 16.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 7.0
# 54.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 6.0
# 29.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 1.0
# 8.0
# Sentiment(polarity=0.10000000000000002, subjectivity=0.3833333333333333)
# 10.0
# 62.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 19.0
# Sentiment(polarity=0.39999999999999997, subjectivity=0.5)
# 6.0
# 19.0
# Sentiment(polarity=0.0, subjectivity=0.6)
# 3.0
# 14.0
# Sentiment(polarity=0.0, subjectivity=0.3)
# 6.0
# 27.0
# Sentiment(polarity=0.375, subjectivity=0.1)
# 8.0
# 20.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 3.0
# 19.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 2.0
# 13.0
# Sentiment(polarity=0.16666666666666666, subjectivity=0.16666666666666666)
# 1.0
# 7.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 10.0
# Sentiment(polarity=0.375, subjectivity=0.2)
# 2.0
# 7.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 5.0
# 22.0
# Sentiment(polarity=0.7, subjectivity=0.8)
# 6.0
# 23.0
# Sentiment(polarity=-0.0625, subjectivity=0.75)
# 7.0
# 23.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 4.0
# 20.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 19.0
# Sentiment(polarity=0.3, subjectivity=0.2)
# 2.0
# 7.0
# Sentiment(polarity=0.55, subjectivity=0.25)
# 8.0
# 26.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 8.0
# 34.0
# Sentiment(polarity=0.9099999999999999, subjectivity=0.7800000000000001)
# 2.0
# 8.0
# Sentiment(polarity=0.375, subjectivity=0.65)
# 5.0
# 28.0
# Sentiment(polarity=0.85, subjectivity=1.0)
# 3.0
# 25.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 4.0
# 17.0
# Sentiment(polarity=0.3, subjectivity=0.5)
# 2.0
# 10.0
# Sentiment(polarity=0.5, subjectivity=0.6)
# 2.0
# 6.0
# Sentiment(polarity=0.6, subjectivity=1.0)
# 1.0
# 4.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 35.0
# Sentiment(polarity=0.5, subjectivity=0.6)
# 2.0
# 6.0
# Sentiment(polarity=-0.8, subjectivity=0.9)
# 3.0
# 12.0
# Sentiment(polarity=0.625, subjectivity=1.0)
# 2.0
# 6.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 25.0
# Sentiment(polarity=0.3, subjectivity=0.2)
# 4.0
# 18.0
# Sentiment(polarity=0.625, subjectivity=0.6)
# 4.0
# 17.0
# Sentiment(polarity=1.0, subjectivity=0.6000000000000001)
# 2.0
# 6.0
# Sentiment(polarity=0.4944444444444444, subjectivity=0.9)
# 9.0
# 50.0
# Sentiment(polarity=0.625, subjectivity=1.0)
# 8.0
# 21.0
# Sentiment(polarity=1.0, subjectivity=0.3)
# 8.0
# 26.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 30.0
# Sentiment(polarity=0.4, subjectivity=0.475)
# 8.0
# 35.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 4.0
# 19.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 1.0
# 8.0
# Sentiment(polarity=0.3, subjectivity=0.4)
# 4.0
# 27.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 1.0
# 7.0
# Sentiment(polarity=0.875, subjectivity=0.8)
# 2.0
# 7.0
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# 17.0
# 60.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 29.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 4.0
# 21.0
# Sentiment(polarity=0.85, subjectivity=1.0)
# 11.0
# 46.0
# Sentiment(polarity=0.25, subjectivity=0.6)
# 10.0
# 42.0
# Sentiment(polarity=0.5, subjectivity=0.6)
# 3.0
# 10.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 2.0
# 11.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 1.0
# 5.0
# Sentiment(polarity=0.31363636363636366, subjectivity=0.7227272727272727)
# 11.0
# 72.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 8.0
# 40.0
# Sentiment(polarity=0.3833333333333333, subjectivity=0.46666666666666673)
# 14.0
# 49.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 23.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 29.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 2.0
# 12.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 6.0
# 27.0
# Sentiment(polarity=-0.1, subjectivity=0.4)
# 3.0
# 14.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 7.0
# 37.0
# Sentiment(polarity=0.525, subjectivity=0.85)
# 2.0
# 8.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 15.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 5.0
# 17.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 1.0
# 4.0
# Sentiment(polarity=0.09999999999999999, subjectivity=0.7666666666666666)
# 9.0
# 39.0
# Sentiment(polarity=0.3125, subjectivity=0.75)
# 4.0
# 13.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 4.0
# 20.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 3.0
# 21.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 7.0
# 40.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 11.0
# 58.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 1.0
# 4.0
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)
# 1.0
# 7.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 3.0
# 9.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 20.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 12.0
# 58.0
# Sentiment(polarity=0.6, subjectivity=0.9)
# 2.0
# 14.0
# Sentiment(polarity=0.3, subjectivity=0.2)
# 3.0
# 13.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 3.0
# 14.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 11.0
# 55.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 1.0
# 8.0
# Sentiment(polarity=-0.1, subjectivity=0.9)
# 14.0
# 59.0
# Sentiment(polarity=0.25, subjectivity=1.0)
# 5.0
# 22.0
# Sentiment(polarity=1.0, subjectivity=1.0)
# 2.0
# 11.0
# Sentiment(polarity=-0.125, subjectivity=0.875)
# 5.0
# 23.0
# Sentiment(polarity=0.15, subjectivity=0.6)
# 8.0
# 32.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 17.0
# Sentiment(polarity=0.375, subjectivity=0.2)
# 9.0
# 36.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 16.0
# Sentiment(polarity=0.4333333333333333, subjectivity=0.7333333333333333)
# 18.0
# 80.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 33.0
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)
# 4.0
# 22.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 7.0
# 40.0
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004)
# 7.0
# 29.0
# Sentiment(polarity=0.5, subjectivity=0.6)
# 5.0
# 23.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 1.0
# 10.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 12.0
# 64.0
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# 8.0
# 28.0
# Sentiment(polarity=0.24166666666666667, subjectivity=0.4134920634920635)
# 14.0
# 67.0
# Sentiment(polarity=0.025, subjectivity=0.4)
# 14.0
# 43.0
# Sentiment(polarity=0.09999999999999998, subjectivity=0.8)
# 9.0
# 28.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 2.0
# 11.0
# Sentiment(polarity=0.65, subjectivity=1.0)
# 3.0
# 12.0
# Sentiment(polarity=0.5, subjectivity=0.6)
# 1.0
# 4.0
# Sentiment(polarity=0.6, subjectivity=0.95)
# 9.0
# 39.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 3.0
# 26.0
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# 5.0
# 24.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 3.0
# 9.0
# Sentiment(polarity=0.5, subjectivity=0.5)
# 5.0
# 22.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 3.0
# 22.0
# Sentiment(polarity=0.0, subjectivity=0.5)
# 4.0
# 17.0
# Sentiment(polarity=0.85, subjectivity=1.0)
# 2.0
# 14.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 10.0
# 47.0
# Sentiment(polarity=0.0, subjectivity=1.0)
# 4.0
# 29.0
# Sentiment(polarity=0.5, subjectivity=0.6)
# 2.0
# 6.0
# Sentiment(polarity=0.9, subjectivity=1.0)
# 1.0
# 9.0
# Sentiment(polarity=0.0, subjectivity=0.3)
# 4.0
# 31.0
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# 2.0
# 8.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 5.0
# 27.0
# Sentiment(polarity=0.4875, subjectivity=0.5)
# 5.0
# 18.0
# Sentiment(polarity=0.625, subjectivity=0.6)
# 5.0
# 20.0
# Sentiment(polarity=0.5, subjectivity=0.75)
# 7.0
# 38.0
# Sentiment(polarity=0.625, subjectivity=0.6)
# 2.0
# 6.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 14.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 10.0
# 40.0
# Sentiment(polarity=0.8, subjectivity=1.0)
# 2.0
# 8.0
# Sentiment(polarity=-0.015384615384615385, subjectivity=0.3807692307692308)
# 3.0
# 10.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 8.0
# 40.0
# Sentiment(polarity=0.78125, subjectivity=1.0)
# 4.0
# 14.0
# Sentiment(polarity=0.7, subjectivity=0.8500000000000001)
# 2.0
# 15.0
# Sentiment(polarity=0.575, subjectivity=0.7)
# 8.0
# 40.0
# Sentiment(polarity=-0.05000000000000002, subjectivity=0.30000000000000004)
# 2.0
# 7.0
# Sentiment(polarity=-0.1, subjectivity=0.2)
# 12.0
# 41.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 7.0
# 30.0
# Sentiment(polarity=0.2, subjectivity=0.5)
# 2.0
# 12.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 16.0
# Sentiment(polarity=0.2, subjectivity=0.9)
# 3.0
# 23.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 5.0
# 21.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 33.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 2.0
# 9.0
# Sentiment(polarity=0.13333333333333333, subjectivity=0.5666666666666668)
# 7.0
# 29.0
# Sentiment(polarity=0.0, subjectivity=0.625)
# 3.0
# 12.0
# Sentiment(polarity=-0.07500000000000001, subjectivity=1.0)
# 3.0
# 23.0
# Sentiment(polarity=0.3, subjectivity=0.2)
# 3.0
# 8.0
# Sentiment(polarity=0.475, subjectivity=0.8)
# 2.0
# 10.0
# Sentiment(polarity=-0.65, subjectivity=1.0)
# 4.0
# 12.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 2.0
# 18.0
# Sentiment(polarity=0.15625, subjectivity=0.75)
# 3.0
# 15.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 23.0
# Sentiment(polarity=0.0, subjectivity=0.1)
# 1.0
# 5.0
# Sentiment(polarity=-0.15, subjectivity=0.8)
# 4.0
# 16.0
# Sentiment(polarity=0.45, subjectivity=0.5)
# 3.0
# 26.0
# Sentiment(polarity=1.0, subjectivity=0.6)
# 9.0
# 34.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 5.0
# 25.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 1.0
# 11.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 24.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 2.0
# 12.0
# Sentiment(polarity=0.75, subjectivity=0.75)
# 23.0
# 105.0
# Sentiment(polarity=0.5, subjectivity=0.5)
# 8.0
# 37.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 5.0
# 25.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 1.0
# 5.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 29.0
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# 5.0
# 15.0
# Sentiment(polarity=0.375, subjectivity=0.2)
# 2.0
# 5.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 5.0
# 23.0
# Sentiment(polarity=0.625, subjectivity=0.5)
# 6.0
# 29.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 6.0
# 39.0
# Sentiment(polarity=0.5, subjectivity=1.0)
# 5.0
# 17.0
# Sentiment(polarity=0.0, subjectivity=0.0)
# 4.0
# 36.0
# Sentiment(polarity=0.5, subjectivity=0.5)
# 6.0
# 30.0
# Sentiment(polarity=1.0, subjectivity=0.75)
# 2.0
# 9.0
# Sentiment(polarity=0.3, subjectivity=0.1)
# 6.0
# 31.0
# Sentiment(polarity=-0.3662109375, subjectivity=0.2)
# 13.0
# 54.0
# Sentiment(polarity=0.875, subjectivity=0.6000000000000001)
# 3.0
# 13.0
# Sentiment(polarity=0.25, subjectivity=1.0)
# 5.0
# 25.0
# Sentiment(polarity=0.8, subjectivity=0.75)
# 5.0
# 30.0
#                                           Review Title Quality
# 0                        Great follow up Grisham book!     0.6
# 1                                           Great book     0.4
# 2                                                 Cute     0.3
# 3    Transforming Through Tiny Changes: A Deep Dive...       0
# 4                  One of my favorite reads this year!     0.5
# ..                                                 ...     ...
# 182               Grisham disappoints,but worth a read     0.3
# 183  DO NOT READ THE EPILOGUE TO THIS BOOK. IT COMP...     0.1
# 184                                   All good things!     0.4
# 185                      Glad I finally started ACOTAR     0.5
# 186                Great book. Damaged during shipping     0.7
#
# [187 rows x 2 columns]

# %%
# Out:
# Accuracy: 0.3404255319148936
# Predicted Quality: ['0' '0.2' '0']
